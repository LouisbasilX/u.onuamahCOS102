# %% [markdown]
# ![project 1.png](<attachment:project 1.png>)

# %%
def getNumberInput(positive, text):
  while True:
    try:
        # 1. Get input and attempt conversion
        user_input = float(input(f"Enter a {text}: "))
        if not positive:
         return user_input
        if user_input <= 0:
         print(f"You have entered a non {text}! Please Enter a {text}")
         continue
        else:
         return user_input   
    except ValueError:
        # 3. This runs only if int() failed
        print("Invalid input. Please enter real numbers only (e.g., 123, 1.2, 2.3).")

principal = getNumberInput(True, "Principal")
rate      = getNumberInput(False, "Rate")
time      = getNumberInput(True, "Positive Time(years)")

simpleInterest = principal * rate * time / 100.0

print("Your Simple Interest is", simpleInterest)
# Out:
# Enter a Principal:  23
# Enter a Rate:  2
# Enter a Positive Time(years):  -12
# You have entered a non Positive Time(years)! Please Enter a Positive Time(years)
# Enter a Positive Time(years):  2
# Your Simple Interest is 0.92
